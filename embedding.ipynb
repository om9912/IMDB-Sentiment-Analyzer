# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# WARNING:tensorflow:From c:\Deep Learning\RNN\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## define the vocabulary size
voc_size = 10000

# %%
## One Hot Representation
one_hot_rep = [one_hot(words,voc_size) for words in sent]
one_hot_rep
# Out:
# [[4150, 130, 4269, 5476],
#  [4150, 130, 4269, 1631],
#  [4150, 4560, 4269, 7757],
#  [7873, 7129, 345, 3667, 6439],
#  [7873, 7129, 345, 3667, 3113],
#  [3482, 4150, 9827, 4269, 5547],
#  [8401, 9163, 4819, 3667]]

# %%
## word embedding repr

from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_len = 8
embedded_docs = pad_sequences(one_hot_rep,padding='pre',maxlen=sent_len)
print(embedded_docs)
# Out:
# [[   0    0    0    0 4150  130 4269 5476]
#  [   0    0    0    0 4150  130 4269 1631]
#  [   0    0    0    0 4150 4560 4269 7757]
#  [   0    0    0 7873 7129  345 3667 6439]
#  [   0    0    0 7873 7129  345 3667 3113]
#  [   0    0    0 3482 4150 9827 4269 5547]
#  [   0    0    0    0 8401 9163 4819 3667]]

# %%
# feature repr
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_len))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Deep Learning\RNN\venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Deep Learning\RNN\venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 227ms/step
# array([[[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [-0.00427079,  0.04032651,  0.00986167, -0.02722185,
#           0.00833225, -0.02568694,  0.03811712, -0.03720104,
#          -0.00313789, -0.00202359],
#         [ 0.04281965, -0.04511715,  0.01385954, -0.02624228,
#           0.0461737 ,  0.00238397, -0.03329463, -0.02205314,
#           0.02301199,  0.0175839 ],
#         [-0.03732558, -0.01430794, -0.03728683, -0.01965382,
#          -0.00805024, -0.00644119, -0.00520266, -0.03109158,
#          -0.04335539, -0.01796101],
#         [-0.02781305,  0.00756777, -0.04779645,  0.04687544,
#           0.00323264,  0.02475343,  0.029939  , -0.03802095,
#           0.03310505, -0.0163578 ]],
#
#        [[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [-0.00427079,  0.04032651,  0.00986167, -0.02722185,
#           0.00833225, -0.02568694,  0.03811712, -0.03720104,
#          -0.00313789, -0.00202359],
#         [ 0.04281965, -0.04511715,  0.01385954, -0.02624228,
#           0.0461737 ,  0.00238397, -0.03329463, -0.02205314,
#           0.02301199,  0.0175839 ],
#         [-0.03732558, -0.01430794, -0.03728683, -0.01965382,
#          -0.00805024, -0.00644119, -0.00520266, -0.03109158,
#          -0.04335539, -0.01796101],
#         [ 0.01299611,  0.01015342,  0.01636297,  0.02442154,
#           0.01584113,  0.03891441, -0.03822405,  0.02494219,
#           0.04725387, -0.04203044]],
#
#        [[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [-0.00427079,  0.04032651,  0.00986167, -0.02722185,
#           0.00833225, -0.02568694,  0.03811712, -0.03720104,
#          -0.00313789, -0.00202359],
#         [ 0.03647606, -0.02228521, -0.04578823, -0.0377024 ,
#           0.00603907, -0.04893987, -0.02197781,  0.04613392,
#          -0.04561771, -0.04902416],
#         [-0.03732558, -0.01430794, -0.03728683, -0.01965382,
#          -0.00805024, -0.00644119, -0.00520266, -0.03109158,
#          -0.04335539, -0.01796101],
#         [-0.02197812, -0.03130271,  0.04716337,  0.04940769,
#           0.03060073,  0.00997172, -0.03598598, -0.003473  ,
#           0.03154583,  0.0092356 ]],
#
#        [[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [-0.00598358,  0.00711063,  0.00474398, -0.03907542,
#          -0.0295183 , -0.04112552, -0.04281911, -0.00642331,
#          -0.04764324,  0.04076939],
#         [ 0.03181672,  0.01573029, -0.03896445, -0.00274394,
#          -0.0158919 , -0.02845293, -0.01821532, -0.02218285,
#           0.0374147 , -0.00133953],
#         [-0.01267483,  0.01683122, -0.01011109, -0.04617507,
#          -0.00222441, -0.0260371 ,  0.04753776, -0.03266754,
#           0.04804386, -0.04115947],
#         [-0.01475447, -0.03917552,  0.03021855,  0.02511266,
#           0.03919432, -0.01653559,  0.00946496, -0.01544859,
#          -0.04408488,  0.00502583],
#         [-0.02619913, -0.0027804 ,  0.00946183, -0.00860522,
#           0.04939583,  0.04679043, -0.00864953,  0.00238727,
#          -0.03584607,  0.02033928]],
#
#        [[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [-0.00598358,  0.00711063,  0.00474398, -0.03907542,
#          -0.0295183 , -0.04112552, -0.04281911, -0.00642331,
#          -0.04764324,  0.04076939],
#         [ 0.03181672,  0.01573029, -0.03896445, -0.00274394,
#          -0.0158919 , -0.02845293, -0.01821532, -0.02218285,
#           0.0374147 , -0.00133953],
#         [-0.01267483,  0.01683122, -0.01011109, -0.04617507,
#          -0.00222441, -0.0260371 ,  0.04753776, -0.03266754,
#           0.04804386, -0.04115947],
#         [-0.01475447, -0.03917552,  0.03021855,  0.02511266,
#           0.03919432, -0.01653559,  0.00946496, -0.01544859,
#          -0.04408488,  0.00502583],
#         [-0.01965506, -0.00524967,  0.02976075, -0.04752618,
#           0.04181064, -0.00261918, -0.01220889,  0.01586212,
#           0.03082031, -0.03901263]],
#
#        [[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [-0.00432888,  0.03203753, -0.01826984,  0.03556185,
#           0.00477295, -0.04564304, -0.01993506,  0.03743762,
#          -0.01193365, -0.0012563 ],
#         [-0.00427079,  0.04032651,  0.00986167, -0.02722185,
#           0.00833225, -0.02568694,  0.03811712, -0.03720104,
#          -0.00313789, -0.00202359],
#         [-0.03453311,  0.01862008,  0.00525175,  0.02194864,
#          -0.03126361,  0.04075916, -0.0293283 , -0.0426383 ,
#           0.04994664,  0.04677894],
#         [-0.03732558, -0.01430794, -0.03728683, -0.01965382,
#          -0.00805024, -0.00644119, -0.00520266, -0.03109158,
#          -0.04335539, -0.01796101],
#         [-0.04704611, -0.01087794, -0.04213572, -0.04652543,
#           0.02469805, -0.01140095, -0.02945147,  0.03536761,
#          -0.01266407,  0.01500776]],
#
#        [[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,
#           0.02676462, -0.03235885,  0.0107939 ,  0.03605935,
#          -0.02828686, -0.0425705 ],
#         [ 0.00490174,  0.01405299, -0.00899059, -0.04730442,
#          -0.02959669,  0.02079983,  0.04707285, -0.04062729,
#           0.0148416 ,  0.04164607],
#         [ 0.00675534, -0.00343293, -0.01840439,  0.039853  ,
#          -0.02884704,  0.0307962 , -0.02057662, -0.04782568,
#           0.0104445 , -0.03134407],
#         [ 0.01532019, -0.01292855,  0.00317521,  0.01912328,
#           0.01764956,  0.03450258,  0.01770911,  0.0012834 ,
#           0.0275329 , -0.04178139],
#         [-0.01475447, -0.03917552,  0.03021855,  0.02511266,
#           0.03919432, -0.01653559,  0.00946496, -0.01544859,
#          -0.04408488,  0.00502583]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 4150,  130, 4269, 5476])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 85ms/step
# array([[ 0.00757559, -0.01635387, -0.01945706, -0.03728276,  0.02676462,
#         -0.03235885,  0.0107939 ,  0.03605935, -0.02828686, -0.0425705 ],
#        [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,  0.02676462,
#         -0.03235885,  0.0107939 ,  0.03605935, -0.02828686, -0.0425705 ],
#        [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,  0.02676462,
#         -0.03235885,  0.0107939 ,  0.03605935, -0.02828686, -0.0425705 ],
#        [ 0.00757559, -0.01635387, -0.01945706, -0.03728276,  0.02676462,
#         -0.03235885,  0.0107939 ,  0.03605935, -0.02828686, -0.0425705 ],
#        [-0.00427079,  0.04032651,  0.00986167, -0.02722185,  0.00833225,
#         -0.02568694,  0.03811712, -0.03720104, -0.00313789, -0.00202359],
#        [ 0.04281965, -0.04511715,  0.01385954, -0.02624228,  0.0461737 ,
#          0.00238397, -0.03329463, -0.02205314,  0.02301199,  0.0175839 ],
#        [-0.03732558, -0.01430794, -0.03728683, -0.01965382, -0.00805024,
#         -0.00644119, -0.00520266, -0.03109158, -0.04335539, -0.01796101],
#        [-0.02781305,  0.00756777, -0.04779645,  0.04687544,  0.00323264,
#          0.02475343,  0.029939  , -0.03802095,  0.03310505, -0.0163578 ]],
#       dtype=float32)
